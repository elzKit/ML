# %%
import pandas as pd;
data = pd.read_csv('fitbit_export_jan_mar_a.csv');

# %%
# %matplotlib inline

# %%
type(data['Minutes Sédentaire'])
data['Minutes Peu actif']
data['Minutes Assez actif']
type(data['Minutes Très actif'])
# Out:
# pandas.core.series.Series

# %%
data
# Out:
#           Date Calories brûlées     Pas Distance  Étages Minutes Sédentaire  \
# 0   01-01-2016            1 491       0        0       0              1 440
# 1   02-01-2016            1 491       0        0       0              1 440
# 2   03-01-2016            1 491       0        0       0              1 440
# 3   04-01-2016            1 491       0        0       0              1 440
# 4   05-01-2016            1 491       0        0       0              1 440
# 5   06-01-2016            1 491       0        0       0              1 440
# 6   07-01-2016            1 491       0        0       0              1 440
# 7   08-01-2016            1 491       0        0       0              1 440
# 8   09-01-2016            1 491       0        0       0              1 440
# 9   10-01-2016            1 993  11 290     7,64       0              1 180
# 10  11-01-2016            2 460  11 419     7,78       0                649
# ...

# %%
import matplotlib.pyplot as plt;

# %%
plt.plot(data.index.values,data['Minutes Très actif'])

# %%
data['Pas']
# Out:
# 0    13 692
# 1    16 639
# 2    21 694
# 3     8 619
# 4    10 437
# 5       262
# 6         0
# Name: Pas, dtype: object

# %%
data.index.values
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
plt.plot(data.index.values, data['Pas'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-ddf4d5ed5dae> in <module>()
# ----> 1 plt.plot(data.index.values, data['Pas'])
#
# C:\Users\Elzbieta\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(*args, **kwargs)
#    3152         ax.hold(hold)
#    3153     try:
# -> 3154         ret = ax.plot(*args, **kwargs)
#    3155     finally:
#    3156         ax.hold(washold)
#
# C:\Users\Elzbieta\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1808                     warnings.warn(msg % (label_namer, func.__name__),
#    1809                                   RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811         pre_doc = inner.__doc__
#    1812         if pre_doc is None:
#
# ...
